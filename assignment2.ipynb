# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammedharkan/ETL-Customer-Feedback-Integration/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Git and GitHub Assignment 2
#
# This notebook demonstrates basic Git operations using Google Colab and GitHub.

# %% [markdown]
# ## Step 1: Confirm Git Installation
#
# The following command verifies that Git is installed and available in the Google Colab environment.

# %%
# !git --version
# Out:
# git version 2.34.1

# %% [markdown]
# ## Step 2: Configure Git Credentials
#
# The following commands configure Git with my GitHub username and email address.

# %%
# !git config --global user.name "Mohammed Harkan"
# !git config --global user.email "mohammed.harkan@students.williscollege.com"

# %% [markdown]
# ## Step 3: Verify Git Configuration
#
# The following command displays the current Git configuration settings.

# %%
# !git config --global --list
# Out:
# user.name=Mohammed Harkan
# user.email=mohammed.harkan@students.williscollege.com

# %% [markdown]
# ## Step 4: Clone the GitHub Repository
#
# The GitHub repository is cloned into the Google Colab environment to allow version control operations directly from the notebook.

# %%
# !git clone https://github.com/Mohammedharkan/colab-git-assignment2-mh.git
# Out:
# Cloning into 'colab-git-assignment2-mh'...
# ...

# %%
# %cd colab-git-assignment2-mh
# Out:
# /content/colab-git-assignment2-mh

# %% [markdown]
# ## Step 5: Verify Repository Contents
#
# The repository contents are displayed to confirm that the repository has been cloned successfully.

# %%
# !ls -la
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Jun 18 21:33 .
# drwxr-xr-x 1 root root 4096 Jun 18 21:33 ..
# drwxr-xr-x 7 root root 4096 Jun 18 21:33 .git

# %% [markdown]
# ## Step 6: Create the Assignment Notebook
#
# The notebook contains Python functions that demonstrate basic programming and will be tracked using Git version control.

# %%
def multiply_numbers(a, b):
    return a * b

print(multiply_numbers(3, 4))
# Out:
# 12

# %% [markdown]
# ## Step 7: Add a Division Function
#
# A second function was added to demonstrate updating the notebook and managing changes through Git branches.

# %%
def divide_numbers(a, b):
    if b != 0:
        return a / b
    else:
        return "Cannot divide by zero"

print(divide_numbers(10, 2))
# Out:
# 5.0

# %% [markdown]
# ## Step 8: Add the Notebook to Git
#
# The notebook is added to the Git staging area so it can be included in the next commit.

# %%
# !git add assignment2.ipynb
# Out:
# fatal: pathspec 'assignment2.ipynb' did not match any files

# %% [markdown]
# ## Step 9: Commit Changes
#
# A commit is created to save the current version of the notebook in the repository history.

# %%
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !pwd
# Out:
# /content/colab-git-assignment2-mh

# %%
# !ls -la
# Out:
# total 12
# drwxr-xr-x 3 root root 4096 Jun 18 21:33 .
# drwxr-xr-x 1 root root 4096 Jun 18 21:33 ..
# drwxr-xr-x 7 root root 4096 Jun 18 22:03 .git
