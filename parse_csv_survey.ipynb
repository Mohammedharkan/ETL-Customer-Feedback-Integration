# %%
# Import required libraries

import csv
import pandas as pd

# %%
# Read CSV file using Python csv module

csv_data = []

with open("customer_survey.csv", "r") as file:
    reader = csv.DictReader(file)

    for row in reader:
        csv_data.append(row)

# Display CSV data
csv_data
# Out:
# [{'customer_id': '1',
#   'name': 'John Doe',
#   'email': 'john.doe@example.com',
#   'region': 'North',
#   'rating': '5',
#   'comments': 'Great product!',
#   'review_date': '2024-01-01'},
#  {'customer_id': '2',
#   'name': 'Jane Smith',
#   'email': 'jane.smith@example.com',
#   'region': 'West',
#   'rating': '4',
#   'comments': 'Fast delivery.',
#   'review_date': '2024-01-02'},
#  {'customer_id': '3',
#   'name': 'Emily Davis',
#   'email': 'emily.davis@example.com',
#   'region': 'South',
#   'rating': '3',
#   'comments': 'Average quality.',
#   'review_date': '2024-01-03'}]
